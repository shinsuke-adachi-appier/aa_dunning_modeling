# %%
import pandas as pd
import os

# %%
cwd = os.getcwd()
parent_of_cwd = os.path.dirname(cwd)
log = pd.read_csv(f"{parent_of_cwd}/artifacts/shadow_log.csv")
slot_log = pd.read_csv(f"{parent_of_cwd}/artifacts/shadow_slot_log.csv")

# %%
slot_log['inference_run_at'].unique()
# Out:
# array(['2026-02-24 13:01:49', '2026-02-24 21:44:14',
#        '2026-02-25 11:35:57', '2026-02-25 23:27:22'], dtype=object)

# %%
log.head()
# Out:
#                        inference_run_id  invoice_id  \
# 0  0150f11f-258c-4cfc-ae4e-17e08833e362     1218660
# 1  0150f11f-258c-4cfc-ae4e-17e08833e362     1224201
# 2  0150f11f-258c-4cfc-ae4e-17e08833e362     1225239
# 3  0150f11f-258c-4cfc-ae4e-17e08833e362     1190717
# 4  0150f11f-258c-4cfc-ae4e-17e08833e362     1234306
#
#                             customer_id     inference_run_at  \
# 0  e7745167-6032-4c0d-af05-75018291edde  2026-02-24 13:01:49
# 1  b8f2146f-53c8-418c-8642-d9620d141ac9  2026-02-24 13:01:49
# 2  b97dc171-701b-407b-8d11-5e6fd76b62b1  2026-02-24 13:01:49
# 3  e6ae2aea-a74e-4184-a9ef-506cedda7d97  2026-02-24 13:01:49
# 4  225e9466-f947-4c1a-b61e-ea5f657c343a  2026-02-24 13:01:49
#
#                        model_version_id  current_attempt_no  snapshot_hour  \
# 0  catboost_dunning_calibrated_20260224                   8             13
# 1  catboost_dunning_calibrated_20260224                   5             13
# ...

# %% [markdown]
# ## Comparison results

# %%
df_comparison = pd.read_csv(f"{parent_of_cwd}/artifacts/shadow_vs_actual_comparison.csv")

# %%
df_comparison
# Out:
#                            inference_run_id  invoice_id  \
# 0      0150f11f-258c-4cfc-ae4e-17e08833e362     1218660
# 1      0150f11f-258c-4cfc-ae4e-17e08833e362     1234351
# 2      0150f11f-258c-4cfc-ae4e-17e08833e362     1252130
# 3      0150f11f-258c-4cfc-ae4e-17e08833e362     1252209
# 4      0150f11f-258c-4cfc-ae4e-17e08833e362     1245968
# ...                                     ...         ...
# 22356  09bb07aa-e341-4a21-938f-27a3523523b5     1256134
# 22357  09bb07aa-e341-4a21-938f-27a3523523b5     1256135
# 22358  09bb07aa-e341-4a21-938f-27a3523523b5     1198502
# 22359  09bb07aa-e341-4a21-938f-27a3523523b5     1229820
# 22360  09bb07aa-e341-4a21-938f-27a3523523b5     1238521
#
#                                 customer_id     inference_run_at  \
# 0      e7745167-6032-4c0d-af05-75018291edde  2026-02-24 13:01:49
# 1      d609a4a0-c778-4250-9de0-5c2365f27ec6  2026-02-24 13:01:49
# 2      5db7d316-3167-44b9-b655-e965e0e49353  2026-02-24 13:01:49
# ...
